# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/SamikshaBurte/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %%
# Setup & Repo Cloning for Colab
import os, sys, subprocess

REPO_URL = "https://github.com/SamikshaBurte/flyrank-ml-internship"
REPO_DIR = "flyrank-ml-internship"

if "google.colab" in sys.modules:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
    os.chdir(f"/content/{REPO_DIR}")

print("Current Working Directory:", os.getcwd())
assert os.path.exists("data/raw/content_refresh_anonymized.csv"), "CSV not found — check folder path"
print("Repo setup complete! CSV found.")
# Out:
# Current Working Directory: /content/flyrank-ml-internship
# Repo setup complete! CSV found.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Setup & Dataset Verification
import pandas as pd
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")
print(f"Total rows in dataset: {len(df):,}")
# Out:
# Total rows in dataset: 30,000

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Target breakdown (Declining vs Non-declining)
declining_count = (df["trend_direction"] == "down").sum()
print(f"Declining pages requiring review: {declining_count:,}")
# Out:
# Declining pages requiring review: 16,262

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Computing 3 real supporting numbers from starter data
total_pages = len(df)
declining_pct = (df["trend_direction"] == "down").mean() * 100
vol_corr = df["search_volume"].corr(df["impressions_90d"])
median_age = df["content_age_days"].median()

print("=== 3 Key Baseline Numbers ===")
print(f"1. Declining Page Ratio      : {declining_pct:.2f}% of total pages")
print(f"2. Search Vol vs Traffic Corr: {vol_corr:.4f} (Near zero correlation)")
print(f"3. Median Content Age         : {median_age:.0f} days")
# Out:
# === 3 Key Baseline Numbers ===
# 1. Declining Page Ratio      : 54.21% of total pages
# 2. Search Vol vs Traffic Corr: 0.0012 (Near zero correlation)
# 3. Median Content Age         : 236 days

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Validation Check: Ensure no sensitive or missing identifiers exist
print("Missing values per key column:")
print(df[["impressions_90d", "ctr", "avg_position", "content_age_days"]].isnull().sum())
print("\nValidation complete: Dataset is clean and ready for modeling.")
# Out:
# Missing values per key column:
# impressions_90d     0
# ctr                 0
# avg_position        0
# content_age_days    0
# dtype: int64
#
# Validation complete: Dataset is clean and ready for modeling.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
